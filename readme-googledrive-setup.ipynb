# %% [markdown]
# <a href="https://colab.research.google.com/github/rby011/hf_study/blob/main/readme-googledrive-setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ☁️ 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 🐍 conda 환경 설정
#
# - condacolab 설치
# - google drive 위치에 conda env 만들고 활성화
# - 해당 conda env 에 필요한 package 설치

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# !conda create --prefix /content/drive/My\ Drive/conda_envs/myenv python=3.10 -y
# !conda activate /content/drive/My\ Drive/conda_envs/myenv

# %%
# !conda install -c conda-forge numpy pandas matplotlib
# !pip install transformers datasets

# %% [markdown]
# ## 🐙 Git 클론하기

# %%
# %cd /content/drive/My Drive/workspace
# !git clone https://github.com/rby011/hf_study.git
# Out:
# /content/drive/My Drive/workspace
# Cloning into 'hf_study'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 53 (delta 4), reused 8 (delta 2), pack-reused 39
# Receiving objects: 100% (53/53), 19.04 MiB | 12.21 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %% [markdown]
# ## ☁️ 허깅페이스 캐시 위치를 구글 드라이브로 지정하기

# %%
import os

# Hugging Face 캐시 디렉토리 설정
os.environ["TRANSFORMERS_CACHE"] = "/content/drive/My Drive/huggingface_cache/models"
os.environ["HF_DATASETS_CACHE"] = "/content/drive/My Drive/huggingface_cache/datasets"

# %%
from transformers import AutoModel

# 모델 로드 (캐시 위치를 사용)
model = AutoModel.from_pretrained("bert-base-uncased")

from datasets import load_dataset

# 데이터셋 로드 (캐시 위치를 사용)
dataset = load_dataset("squad")
# Out:
# /usr/local/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]
